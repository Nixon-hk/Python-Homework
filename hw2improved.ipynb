# %%
import numpy as np
import pandas as pd

# %%
traindata = pd.read_csv("/Users/acer/Documents/test1.csv")
traindata.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  \
# 0      404466         96517   96518    -0.068    -0.101     0.312     0.312
# 1      212970        172218  172219       NaN       NaN       NaN       NaN
# 2      164141        158398  158399       NaN       NaN       NaN       NaN
# 3      392144        814990  814991       NaN       NaN       NaN       NaN
# 4      339808        569391  569392     0.062     0.086    -0.343    -0.325
#
#    L0_S0_F8  L0_S0_F10  L0_S0_F12  ...  L3_S50_F4245  L3_S50_F4247  \
# 0     0.031      0.070       0.03  ...           NaN           NaN
# 1       NaN        NaN        NaN  ...           NaN           NaN
# 2       NaN        NaN        NaN  ...           0.0           0.0
# 3       NaN        NaN        NaN  ...           NaN           NaN
# 4     0.031      0.161      -0.03  ...           NaN           NaN
#
#    L3_S50_F4249  L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  L3_S51_F4258  \
# ...

# %%
# split traindata into two parts then, output as table and restart again 
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(traindata, test_size=0.2)

# %%
traindata.columns.isna()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
train.shape
# Out:
# (66290, 972)

# %%
test.shape
# Out:
# (16573, 972)

# %%
train.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1      Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  \
# 63200       50355         60697   60698    -0.082    -0.078     0.294
# 53169      167118        336507  336508    -0.199    -0.250    -0.215
# 44814      144774         97398   97399     0.069     0.078    -0.197
# 27769      306666        807046  807047       NaN       NaN       NaN
# 67878      252672         47945   47946    -0.029    -0.026    -0.197
#
#        L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  ...  L3_S50_F4245  \
# 63200     0.330    -0.056     -0.248      0.037  ...           NaN
# 53169    -0.179    -0.013      0.116      0.030  ...           NaN
# 44814    -0.197     0.031      0.025     -0.022  ...           NaN
# 27769       NaN       NaN        NaN        NaN  ...           NaN
# 67878    -0.216     0.074     -0.021     -0.007  ...           NaN
#
#        L3_S50_F4247  L3_S50_F4249  L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  \
# ...

# %%
train = train.replace(np.nan,0)

# %%
test = test.replace(np.nan,0)

# %%
test.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1      Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  \
# 81828      369332        505155  505156     0.000     0.000     0.000
# 36224       54260        538408  538409     0.000     0.000     0.000
# 20268      213527        455651  455652     0.023    -0.026    -0.179
# 35004      208512        584163  584164     0.000     0.000     0.000
# 64289      187426        490807  490808    -0.062    -0.123     0.003
#
#        L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  ...  L3_S50_F4245  \
# 81828     0.000     0.000      0.000      0.000  ...           0.0
# 36224     0.000     0.000      0.000      0.000  ...           0.0
# 20268    -0.179     0.031      0.161     -0.015  ...           0.0
# 35004     0.000     0.000      0.000      0.000  ...           0.0
# 64289    -0.034    -0.056     -0.248      0.015  ...           0.0
#
#        L3_S50_F4247  L3_S50_F4249  L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  \
# ...

# %%
X_test = test.drop('Response', axis=1)
y_test=  test['Response']

# %%
X_train = train.drop('Response', axis=1)
y_train =  train['Response']

# %%
y_train.head()
# Out:
# 63200    0
# 53169    0
# 44814    0
# 27769    0
# 67878    0
# Name: Response, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100, random_state=24)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=24, verbose=0,
#                        warm_start=False)

# %%
y_pred = clf.predict(X_test)
from sklearn.metrics import accuracy_score

print("Random Forests accuracy", accuracy_score(y_test, y_pred))
# Out:
# Random Forests accuracy 0.993061002835938

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(criterion='gini', random_state=21, max_depth=10)

dtree.fit(X_train, y_train)
tree_pred = dtree.predict(X_test)

print("Decision Tree accuracy: ", accuracy_score(y_test, tree_pred))
# Out:
# Decision Tree accuracy:  0.993061002835938
